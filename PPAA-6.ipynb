# %% [markdown]
# Ans 1.

# %%
def find_the_dif(s,s1):
    s2=s1.replace(s,"")
    return s2

# %%
find_the_dif("abcd","abcde")
# Out:
# 'e'

# %%
find_the_dif('','y')
# Out:
# 'y'

# %%
find_the_dif("ae","aea")
# Out:
# 'a'

# %% [markdown]
# Ans 2.

# %%
from collections import OrderedDict

def count_datatypes(*args):
    if not args:
        return [0, 0, 0, 0, 0, 0]

    types = {int: 0, str: 0, bool: 0, list: 0, tuple: 0, dict: 0}
    od = OrderedDict([(int, 0), (str, 0), (bool, 0), (list, 0), (tuple, 0), (dict, 0)])

    for k, v in types.items():
        for a in args:
            if type(a) == k:
                od[k] += 1

    res = [i for i in od.values()]

    return res

# %%
count_datatypes(1, 45, "Hi", False)
# Out:
# [2, 1, 1, 0, 0, 0]

# %%
count_datatypes([10, 20], ("t", "Ok"), 2, 3, 1)
# Out:
# [3, 0, 0, 1, 1, 0]

# %% [markdown]
# Ans 3.

# %%
def fib_str(n,arr):
    if n==1:
        return a
    else:
        for i in range(2,n):
            a=arr[0]
            b=arr[1]
            c=b+a
            a=b
            b=c
            
    return a,b,c

# %%
fib_str(5, ["e", "a"])
# Out:
# ('a', 'ae', 'ae')

# %% [markdown]
# Ans 5.

# %%
def fib(n):
        a=0
        b=1
        if n==1:
            return 1
        else:
            for i in range(2,n+1):
                c=a+b
                a=b
                b=c
        return c

# %%
fib(6)
# Out:
# 8

# %%
fib(1)
# Out:
# 1

# %%
fib(2)
# Out:
# 1

# %%
def fib1(limit,arr): 
    counter = 0 
    first = arr[0] 
    secnd = arr[1] 
    shift = "" 
  
    while counter <= limit:
        print(first) 
        shift = first + secnd 
        first = secnd 
        secnd = shift 
        counter+=1

# %%
fib1(3,['e','a'])
